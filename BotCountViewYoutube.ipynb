# %%
import tweepy
import pandas as pd
import time
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pytz
#Vn_time="VN time: "+ datetime_Vn.strftime("%H:%M:%S")
#Kr_time="KR time: "+ datetime_Kr.strftime("%H:%M:%S")
#print(Vn_time)
#print(Kr_time)

#temp=int(soup.select_one('meta[itemprop="interactionCount"][content]')['content'])
#print(int(view))
#view="{:,}".format(temp)
#print(view)
def tweet_now(msg):
    msg = msg[0:270]
    try:

        auth = tweepy.OAuthHandler('1w3RjrhjjrDwdCoiFcTvpkrjX', 'eUlivCACXZ22OKH5xPpx1dCFpltB4AuOTPsxtxV8Rv3Vlwd5jz')
        auth.set_access_token('1256199178209775617-jWN4bsztSOqNmAkJY8cRqpYImkoIX2', 'cyLFj2380x9luctWeRnkDSJJhT6mnkQ8BFoxqgkURcaCb')
        api = tweepy.API(auth)
        try:
            api.verify_credentials()
            print("Authentication OK")
        except:
            print("Error during authentication")
        api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
        api.update_status(msg)
        print(msg)

        print("Tweeted")
    
    except Exception as e:
        print(e)
tem1=2
tem2=19
while True:  
  #Let's split the line into an array called "fields" using the ";" as a separator:
    #fields = line.split(";")
  
  #and let's extract the data:
    #quote = fields[0]
    #author = fields[1]
    Vn = pytz.timezone('Asia/Ho_Chi_Minh') 
    datetime_Vn = datetime.now(Vn)
    Kr = pytz.timezone('Asia/Seoul') 
    datetime_Kr = datetime.now(Kr)
    #Vn_time="VN time: "+ datetime_Vn.strftime("%H:%M:%S")
    Kr_time="KR time: "+ datetime_Kr.strftime("%H:%M:%S")
    url = 'https://www.youtube.com/watch?v=R9At2ICm4LQ'
    soup = BeautifulSoup(requests.get(url).text, 'lxml')
    #print(soup)
    temp=int(soup.select_one('meta[itemprop="interactionCount"][content]')['content'])
    view="{:,}".format(temp)
    #print(type(view))
    temp1=int(temp/1000000)
    #import tweepy
    #url1 = 'https://kworb.net/youtube/trending.html'
    #soup1 = BeautifulSoup(requests.get(url1).text, 'lxml')
    #print(soup)
    #table = soup1.find(id='trendingoverall')
    #print(table)
    #dem=1;
    #tam=0;
    #video='/youtube/trending/video/c9RzZpV460k.html'
    #for row in table.find_all('tr'):
    #   for col in row.find_all('td'):
    #        for div in col.find_all('div'):
    #            for a in div.find_all('a'):
    #                if a.get('href') == video:
    #                    print(dem)
    #                    tam=dem;
    #                else:
    #                    dem=dem+1
    #print(tam)
    hashtags = '\nStream: https://www.youtube.com/watch?v=R9At2ICm4LQ\n\nCAN YOU FEEL MY RHYTHM\n#RedVelvetComeBach\n#WelcomeToRVF2022\n@RVsmtown '
    #if tam==0:
    #    top='\n'
    #else:
    #    top='#'+str(tam)+' Music videos trending worldwide'
    #print(Kr_time+'\n'+view+" views" + '\n'+top +'\n'+ hashtags+"\nThis tweet is automatically generated")
    temp2=int(temp/100000)
    if tem2==temp2:
        tweet_now("FEEL MY RHYTHM MV is now less than 100k views away from " +str(tem1)+"M views on YouTube!\nKeep streaming!!!\n"+hashtags+"\n\nThis tweet is automatically generated")
        tem2=tem2+10
        time.sleep(200)
    if tem1==temp1:
        tweet_now("FEEL MY RHYTHM MV has now surpassed "+str(tem1)+"M views on Youtube \n"+hashtags+"\n\nThis tweet is automatically generated")
        print("done")
        tem1=tem1+1
        time.sleep(1800)
    time.sleep(100)
# Out:
# Authentication OK
# FEEL MY RHYTHM MV is now less than 100k views away from 2M views on YouTube!
# Keep streaming!!!
#
# Stream: https://www.youtube.com/watch?v=R9At2ICm4LQ
#
# CAN YOU FEEL MY RHYTHM
# #RedVelvetComeBach
# #WelcomeToRVF2022
# @RVsmtown
#
# This tweet is automatically generated
# Tweeted
# Authentication OK
# FEEL MY RHYTHM MV has now surpassed 2M views on Youtube
#
# Stream: https://www.youtube.com/watch?v=R9At2ICm4LQ
#
# CAN YOU FEEL MY RHYTHM
# #RedVelvetComeBach
# #WelcomeToRVF2022
# @RVsmtown
#
# This tweet is automatically generated
# Tweeted
# done

# %%
import tweepy
import pandas as pd
import time
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pytz
#Vn_time="VN time: "+ datetime_Vn.strftime("%H:%M:%S")
#Kr_time="KR time: "+ datetime_Kr.strftime("%H:%M:%S")
#print(Vn_time)
#print(Kr_time)

#temp=int(soup.select_one('meta[itemprop="interactionCount"][content]')['content'])
#print(int(view))
#view="{:,}".format(temp)
#print(view)
def tweet_now(msg):
    msg = msg[0:270]
    try:

        auth = tweepy.OAuthHandler('1w3RjrhjjrDwdCoiFcTvpkrjX', 'eUlivCACXZ22OKH5xPpx1dCFpltB4AuOTPsxtxV8Rv3Vlwd5jz')
        auth.set_access_token('1256199178209775617-jWN4bsztSOqNmAkJY8cRqpYImkoIX2', 'cyLFj2380x9luctWeRnkDSJJhT6mnkQ8BFoxqgkURcaCb')
        api = tweepy.API(auth)
        try:
            api.verify_credentials()
            print("Authentication OK")
        except:
            print("Error during authentication")
        api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
        api.update_status(msg)
        print(msg)

        print("Tweeted")
    
    except Exception as e:
        print(e)
tem1=5
while True:  
  #Let's split the line into an array called "fields" using the ";" as a separator:
    #fields = line.split(";")
  
  #and let's extract the data:
    #quote = fields[0]
    #author = fields[1]
    Vn = pytz.timezone('Asia/Ho_Chi_Minh') 
    datetime_Vn = datetime.now(Vn)
    Kr = pytz.timezone('Asia/Seoul') 
    datetime_Kr = datetime.now(Kr)
    #Vn_time="VN time: "+ datetime_Vn.strftime("%H:%M:%S")
    Kr_time="KR time: "+ datetime_Kr.strftime("%H:%M:%S")
    url = 'https://www.youtube.com/watch?v=R9At2ICm4LQ'
    soup = BeautifulSoup(requests.get(url).text, 'lxml')
    #print(soup)
    temp=int(soup.select_one('meta[itemprop="interactionCount"][content]')['content'])
    view="{:,}".format(temp)
    #print(type(view))
    temp1=int(temp/100000)
    #import tweepy
    #url1 = 'https://kworb.net/youtube/trending.html'
    #soup1 = BeautifulSoup(requests.get(url1).text, 'lxml')
    #print(soup)
    #table = soup1.find(id='trendingoverall')
    #print(table)
    #dem=1;
    #tam=0;
    #video='/youtube/trending/video/c9RzZpV460k.html'
    #for row in table.find_all('tr'):
    #   for col in row.find_all('td'):
    #        for div in col.find_all('div'):
    #            for a in div.find_all('a'):
    #                if a.get('href') == video:
    #                    print(dem)
    #                    tam=dem;
    #                else:
    #                    dem=dem+1
    #print(tam)
    hashtags = '\nStream: https://www.youtube.com/watch?v=R9At2ICm4LQ\n\nFEEL MY RHYTHM\n#RedVelvetComeBach\n#WelcomeToRVF2022\n@RVsmtown '
    #if tam==0:
    #    top='\n'
    #else:
    #    top='#'+str(tam)+' Music videos trending worldwide'
    #print(Kr_time+'\n'+view+" views" + '\n'+top +'\n'+ hashtags+"\nThis tweet is automatically generated")
    if tem1==temp1:
        tweet_now("FEEL MY RHYTHM MV has now surpassed "+str(tem1)+"00k views on Youtube \n"+hashtags+"\n\nThis tweet is automatically generated")
        print("done")
        tem1=tem1+1
        time.sleep(200)
    time.sleep(3)
# Out:
# Authentication OK
# FEEL MY RHYTHM MV has now surpassed 500k views on Youtube
#
# Stream: https://www.youtube.com/watch?v=R9At2ICm4LQ
#
# FEEL MY RHYTHM
# #RedVelvetComeBach
# #WelcomeToRVF2022
# @RVsmtown
#
# This tweet is automatically generated
# Tweeted
# done
# Authentication OK
# FEEL MY RHYTHM MV has now surpassed 600k views on Youtube
#
# Stream: https://www.youtube.com/watch?v=R9At2ICm4LQ
#
# FEEL MY RHYTHM
# #RedVelvetComeBach
# #WelcomeToRVF2022
# @RVsmtown
#
# This tweet is automatically generated
# Tweeted
# done
# Authentication OK
# FEEL MY RHYTHM MV has now surpassed 700k views on Youtube
#
# Stream: https://www.youtube.com/watch?v=R9At2ICm4LQ
#
# FEEL MY RHYTHM
# #RedVelvetComeBach
# #WelcomeToRVF2022
# @RVsmtown
#
# This tweet is automatically generated
# Tweeted
# done
# Authentication OK
# FEEL MY RHYTHM MV has now surpassed 800k views on Youtube
#
# Stream: https://www.youtube.com/watch?v=R9At2ICm4LQ
#
# FEEL MY RHYTHM
# #RedVelvetComeBach
# #WelcomeToRVF2022
# ...
